# %% [markdown]
# ## Data Science Global Bootcamp
# ### Data Normalization & Probability: Assignment 02

# %% [markdown]
# # Q1

# %%
import numpy as np
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\theco\\Downloads'

# %%
# Read the CSV file into a DataFrame: df
gapminder_df = pd.read_csv('C:\\Users\\theco\\Downloads\\gapminder.csv')

gapminder_df
# Out:
#      population  fertility   HIV        CO2  BMI_male      GDP  BMI_female  \
# 0    34811059.0       2.73   0.1   3.328945  24.59620  12314.0    129.9049
# 1    19842251.0       6.43   2.0   1.474353  22.25083   7103.0    130.1247
# 2    40381860.0       2.24   0.5   4.785170  27.50170  14646.0    118.8915
# 3     2975029.0       1.40   0.1   1.804106  25.35542   7383.0    132.8108
# 4    21370348.0       1.96   0.1  18.016313  27.56373  41312.0    117.3755
# ..          ...        ...   ...        ...       ...      ...         ...
# 134   3350832.0       2.11   0.5   2.489764  26.39123  15317.0    124.2604
# 135  26952719.0       2.46   0.1   4.476669  25.32054   3733.0    124.3462
# 136  86589342.0       1.86   0.4   1.479347  20.91630   4085.0    121.9367
# 137  13114579.0       5.88  13.6   0.148982  20.68321   3039.0    132.4493
# 138  13495462.0       3.85  15.1   0.654323  22.02660   1286.0    131.9745
#
#      life  child_mortality                      Region
# ...

# %%
gapminder_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   population       139 non-null    float64
#  1   fertility        139 non-null    float64
#  2   HIV              139 non-null    float64
#  3   CO2              139 non-null    float64
#  4   BMI_male         139 non-null    float64
#  5   GDP              139 non-null    float64
#  6   BMI_female       139 non-null    float64
#  7   life             139 non-null    float64
#  8   child_mortality  139 non-null    float64
#  9   Region           139 non-null    object
# dtypes: float64(9), object(1)
# memory usage: 11.0+ KB

# %%
gapminder_df.head()
# Out:
#    population  fertility  HIV        CO2  BMI_male      GDP  BMI_female  life  \
# 0  34811059.0       2.73  0.1   3.328945  24.59620  12314.0    129.9049  75.3
# 1  19842251.0       6.43  2.0   1.474353  22.25083   7103.0    130.1247  58.3
# 2  40381860.0       2.24  0.5   4.785170  27.50170  14646.0    118.8915  75.5
# 3   2975029.0       1.40  0.1   1.804106  25.35542   7383.0    132.8108  72.5
# 4  21370348.0       1.96  0.1  18.016313  27.56373  41312.0    117.3755  81.5
#
#    child_mortality                      Region
# 0             29.5  Middle East & North Africa
# 1            192.0          Sub-Saharan Africa
# 2             15.4                     America
# 3             20.0       Europe & Central Asia
# 4              5.2         East Asia & Pacific

# %%
gapminder_df.describe()
# Out:
#          population   fertility         HIV         CO2    BMI_male  \
# count  1.390000e+02  139.000000  139.000000  139.000000  139.000000
# mean   3.549977e+07    3.005108    1.915612    4.459874   24.623054
# std    1.095121e+08    1.615354    4.408974    6.268349    2.209368
# min    2.773150e+05    1.280000    0.060000    0.008618   20.397420
# 25%    3.752776e+06    1.810000    0.100000    0.496190   22.448135
# 50%    9.705130e+06    2.410000    0.400000    2.223796   25.156990
# 75%    2.791973e+07    4.095000    1.300000    6.589156   26.497575
# max    1.197070e+09    7.590000   25.900000   48.702062   28.456980
#
#                  GDP  BMI_female        life  child_mortality
# count     139.000000  139.000000  139.000000       139.000000
# mean    16638.784173  126.701914   69.602878        45.097122
# std     19207.299083    4.471997    9.122189        45.724667
# min       588.000000  117.375500   45.200000         2.700000
# ...

# %% [markdown]
# ### Use encoding techniques (One hot encoding and Label encoding) for the category column “Region”

# %%
from sklearn.preprocessing import LabelEncoder

# %%
gapminder_df["Region"].unique()
# Out:
# array(['Middle East & North Africa', 'Sub-Saharan Africa', 'America',
#        'Europe & Central Asia', 'East Asia & Pacific', 'South Asia'],
#       dtype=object)

# %% [markdown]
# ### Label Encoding

# %%
lbl_encode = LabelEncoder()

# %%
lbl_encode
# Out:
# LabelEncoder()

# %%
lbl_encode.fit_transform(gapminder_df["Region"])
# Out:
# array([3, 5, 0, 2, 1, 2, 2, 0, 4, 0, 2, 2, 0, 5, 4, 0, 5, 0, 2, 5, 5, 1,
#        5, 0, 5, 0, 0, 5, 5, 0, 5, 2, 0, 2, 3, 0, 3, 0, 5, 5, 2, 1, 2, 2,
#        5, 5, 2, 2, 5, 2, 0, 5, 5, 0, 0, 0, 2, 2, 4, 1, 3, 2, 3, 2, 0, 1,
#        2, 5, 2, 3, 5, 5, 2, 2, 5, 5, 1, 4, 5, 2, 5, 5, 0, 2, 1, 3, 5, 1,
#        4, 2, 1, 0, 5, 5, 2, 3, 4, 0, 1, 0, 0, 1, 2, 2, 3, 2, 2, 5, 5, 2,
#        5, 1, 2, 2, 5, 5, 2, 4, 5, 0, 5, 2, 2, 2, 5, 1, 5, 0, 3, 2, 5, 2,
#        2, 0, 0, 2, 1, 5, 5])

# %%
gapminder_df["Region_label"] = lbl_encode.fit_transform(gapminder_df["Region"])

# %%
gapminder_df["Region_label"].value_counts()
# Out:
# 2    41
# 5    40
# 0    27
# 1    14
# 3    10
# 4     7
# Name: Region_label, dtype: int64

# %%
gapminder_df["Region"].value_counts()
# Out:
# Europe & Central Asia         41
# Sub-Saharan Africa            40
# America                       27
# East Asia & Pacific           14
# Middle East & North Africa    10
# South Asia                     7
# Name: Region, dtype: int64

# %% [markdown]
# By comparing the outputs of lines 34 and 35, we observe that it is in the right order. Hence, the categorical variable "Region" has been transformed to numerical values as seen in line 34.

# %% [markdown]
# ## One-hot Encoding

# %% [markdown]
# ### Create dummy variables: gapminder_df1

# %%
gapminder_df1 = pd.get_dummies(gapminder_df["Region"])

# %%
gapminder_df1
# Out:
#      America  East Asia & Pacific  Europe & Central Asia  \
# 0          0                    0                      0
# 1          0                    0                      0
# 2          1                    0                      0
# 3          0                    0                      1
# 4          0                    1                      0
# ..       ...                  ...                    ...
# 134        1                    0                      0
# 135        0                    0                      1
# 136        0                    1                      0
# 137        0                    0                      0
# 138        0                    0                      0
#
#      Middle East & North Africa  South Asia  Sub-Saharan Africa
# 0                             1           0                   0
# 1                             0           0                   1
# 2                             0           0                   0
# ...

# %%
gapminder_df.join(gapminder_df1)
# Out:
#      population  fertility   HIV        CO2  BMI_male      GDP  BMI_female  \
# 0    34811059.0       2.73   0.1   3.328945  24.59620  12314.0    129.9049
# 1    19842251.0       6.43   2.0   1.474353  22.25083   7103.0    130.1247
# 2    40381860.0       2.24   0.5   4.785170  27.50170  14646.0    118.8915
# 3     2975029.0       1.40   0.1   1.804106  25.35542   7383.0    132.8108
# 4    21370348.0       1.96   0.1  18.016313  27.56373  41312.0    117.3755
# ..          ...        ...   ...        ...       ...      ...         ...
# 134   3350832.0       2.11   0.5   2.489764  26.39123  15317.0    124.2604
# 135  26952719.0       2.46   0.1   4.476669  25.32054   3733.0    124.3462
# 136  86589342.0       1.86   0.4   1.479347  20.91630   4085.0    121.9367
# 137  13114579.0       5.88  13.6   0.148982  20.68321   3039.0    132.4493
# 138  13495462.0       3.85  15.1   0.654323  22.02660   1286.0    131.9745
#
# ...

# %%
gapminder_df.drop(["Region"], axis = 1, inplace = True)

# %%
gapminder_df.columns
# Out:
# Index(['population', 'fertility', 'HIV', 'CO2', 'BMI_male', 'GDP',
#        'BMI_female', 'life', 'child_mortality', 'Region_label'],
#       dtype='object')

# %%
gapminder_df = gapminder_df.join(gapminder_df1)

# %%
gapminder_df
# Out:
#      population  fertility   HIV        CO2  BMI_male      GDP  BMI_female  \
# 0    34811059.0       2.73   0.1   3.328945  24.59620  12314.0    129.9049
# 1    19842251.0       6.43   2.0   1.474353  22.25083   7103.0    130.1247
# 2    40381860.0       2.24   0.5   4.785170  27.50170  14646.0    118.8915
# 3     2975029.0       1.40   0.1   1.804106  25.35542   7383.0    132.8108
# 4    21370348.0       1.96   0.1  18.016313  27.56373  41312.0    117.3755
# ..          ...        ...   ...        ...       ...      ...         ...
# 134   3350832.0       2.11   0.5   2.489764  26.39123  15317.0    124.2604
# 135  26952719.0       2.46   0.1   4.476669  25.32054   3733.0    124.3462
# 136  86589342.0       1.86   0.4   1.479347  20.91630   4085.0    121.9367
# 137  13114579.0       5.88  13.6   0.148982  20.68321   3039.0    132.4493
# 138  13495462.0       3.85  15.1   0.654323  22.02660   1286.0    131.9745
#
# ...

# %% [markdown]
# Since we have about six (6) possible values of the categorical variable "Region", one hot encoding is preferrable, which only gives binary representation of these possible values.

# %% [markdown]
# # Q2

# %%
wine_df = pd.read_csv('C:\\Users\\theco\\Downloads\\wine_data_UCI.csv')

wine_df
# Out:
#      quality  Alcohol  Malicacid   Ash  Alcalinity_of_ash  Magnesium  \
# 0          1    14.23       1.71  2.43               15.6        127
# 1          1    13.20       1.78  2.14               11.2        100
# 2          1    13.16       2.36  2.67               18.6        101
# 3          1    14.37       1.95  2.50               16.8        113
# 4          1    13.24       2.59  2.87               21.0        118
# ..       ...      ...        ...   ...                ...        ...
# 173        3    13.71       5.65  2.45               20.5         95
# 174        3    13.40       3.91  2.48               23.0        102
# 175        3    13.27       4.28  2.26               20.0        120
# 176        3    13.17       2.59  2.37               20.0        120
# 177        3    14.13       4.10  2.74               24.5         96
#
#      Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# ...

# %%
wine_df['quality']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: quality, Length: 178, dtype: int64

# %%
wine_df['Alcohol']
# Out:
# 0      14.23
# 1      13.20
# 2      13.16
# 3      14.37
# 4      13.24
#        ...
# 173    13.71
# 174    13.40
# 175    13.27
# 176    13.17
# 177    14.13
# Name: Alcohol, Length: 178, dtype: float64

# %%
wine_df['Malicacid']
# Out:
# 0      1.71
# 1      1.78
# 2      2.36
# 3      1.95
# 4      2.59
#        ...
# 173    5.65
# 174    3.91
# 175    4.28
# 176    2.59
# 177    4.10
# Name: Malicacid, Length: 178, dtype: float64

# %% [markdown]
# ##### Consider the features - the wine quality i.e. "quality", "Alcohol" (percent/volume) and "Malicacid" (g/l). Q2: Do you think feature scaling is required? If yes - Why, If no - why

# %% [markdown]
# Yes! By considering the featues- the wine quality, there is need for feature scaling so as to achieve the proper convergence of the gradient descent. In addition to this, it helpps to put all features within the same scale.

# %% [markdown]
# # Q3

# %% [markdown]
# ####  If you feel feature scaling is required, then perform Standardization and Normalization and provide your result. What is the difference you observe between these two methods?

# %%
wine_df.describe()
# Out:
#           quality     Alcohol   Malicacid         Ash  Alcalinity_of_ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total_phenols  Flavanoids  Nonflavanoid_phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %%
wine_qAM = wine_df.loc[1:178, ['quality', 'Alcohol', 'Malicacid']]

# %%
wine_qAM
# Out:
#      quality  Alcohol  Malicacid
# 1          1    13.20       1.78
# 2          1    13.16       2.36
# 3          1    14.37       1.95
# 4          1    13.24       2.59
# 5          1    14.20       1.76
# ..       ...      ...        ...
# 173        3    13.71       5.65
# 174        3    13.40       3.91
# 175        3    13.27       4.28
# 176        3    13.17       2.59
# 177        3    14.13       4.10
#
# [177 rows x 3 columns]

# %% [markdown]
# ### Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
wine_df1 = scaler.fit_transform(wine_qAM)

# %%
wine_df1
# Out:
# array([[0.        , 0.57105263, 0.2055336 ],
#        [0.        , 0.56052632, 0.3201581 ],
#        [0.        , 0.87894737, 0.23913043],
#        [0.        , 0.58157895, 0.36561265],
#        [0.        , 0.83421053, 0.20158103],
#        [0.        , 0.88421053, 0.22332016],
#        [0.        , 0.79736842, 0.27865613],
#        [0.        , 1.        , 0.17786561],
#        [0.        , 0.74473684, 0.12055336],
#        [0.        , 0.80789474, 0.28063241],
#        [0.        , 0.81315789, 0.14624506],
#        [0.        , 0.71578947, 0.19565217],
#        [0.        , 0.97894737, 0.19565217],
#        [0.        , 0.88157895, 0.22332016],
#        [0.        , 0.68421053, 0.21146245],
#        [0.        , 0.86052632, 0.23320158],
#        [0.        , 0.73684211, 0.16403162],
#        [0.        , 0.83157895, 0.16798419],
#        [0.        , 0.68684211, 0.46640316],
#        [0.        , 0.79736842, 0.17588933],
#        [0.        , 0.5       , 0.60474308],
# ...

# %% [markdown]
# ### Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
wine_df2 = scaler.fit_transform(wine_qAM)

# %%
wine_df2
# Out:
# array([[-1.22246766,  0.2558245 , -0.50162433],
#        [-1.22246766,  0.20622873,  0.01802001],
#        [-1.22246766,  1.70650069, -0.34931478],
#        [-1.22246766,  0.30542026,  0.22408586],
#        [-1.22246766,  1.49571868, -0.5195431 ],
#        [-1.22246766,  1.73129858, -0.42098986],
#        [-1.22246766,  1.32213349, -0.17012708],
#        [-1.22246766,  2.27685202, -0.62705572],
#        [-1.22246766,  1.07415466, -0.88687789],
#        [-1.22246766,  1.37172926, -0.1611677 ],
#        [-1.22246766,  1.39652715, -0.77040588],
#        [-1.22246766,  0.9377663 , -0.54642125],
#        [-1.22246766,  2.17766048, -0.54642125],
#        [-1.22246766,  1.71889963, -0.42098986],
#        [-1.22246766,  0.788979  , -0.47474617],
#        [-1.22246766,  1.6197081 , -0.37619294],
#        [-1.22246766,  1.03695783, -0.68977141],
#        [-1.22246766,  1.48331974, -0.67185264],
#        [-1.22246766,  0.80137794,  0.6810145 ],
#        [-1.22246766,  1.32213349, -0.6360151 ],
# ...

# %%
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.pairplot(wine_qAM)

# %%
wine_df.describe().round(2)
# Out:
#        quality  Alcohol  Malicacid     Ash  Alcalinity_of_ash  Magnesium  \
# count   178.00   178.00     178.00  178.00             178.00     178.00
# mean      1.94    13.00       2.34    2.37              19.49      99.74
# std       0.78     0.81       1.12    0.27               3.34      14.28
# min       1.00    11.03       0.74    1.36              10.60      70.00
# 25%       1.00    12.36       1.60    2.21              17.20      88.00
# 50%       2.00    13.05       1.87    2.36              19.50      98.00
# 75%       3.00    13.68       3.08    2.56              21.50     107.00
# max       3.00    14.83       5.80    3.23              30.00     162.00
#
#        Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# count         178.00      178.00                178.00           178.00
# mean            2.30        2.03                  0.36             1.59
# std             0.63        1.00                  0.12             0.57
# ...

# %%
wine_qAM.describe().round(2)
# Out:
#        quality  Alcohol  Malicacid
# count   177.00   177.00     177.00
# mean      1.94    12.99       2.34
# std       0.77     0.81       1.12
# min       1.00    11.03       0.74
# 25%       1.00    12.36       1.60
# 50%       2.00    13.05       1.87
# 75%       3.00    13.67       3.10
# max       3.00    14.83       5.80
